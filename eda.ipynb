# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# read in the data
df = pd.read_csv("data/train.csv")

# %%
df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
df.describe()
# the variables are not scaled
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
# check for balance in classes - there are about 10% 1s, so we will have to resample/stratified sample
sum(df['target']) / len(df)
# Out:
# 0.10049

# %%
# at this point we will do train test split and perform the rest of the eda on the development split
dev_df, holdout_df = train_test_split(df, stratify = df['target'], test_size = 0.2)

# %%
# holdout_df.to_csv("data/holdout.csv")
# dev_df.to_csv("data/dev.csv")

# %%
corr_df = dev_df.drop(columns='ID_code').corr() # check correlations

# %%
corr_df[['target']].iloc[1:][corr_df['target'].iloc[1:] == corr_df['target'].iloc[1:].max()]
 # var 6 with the greatest correlation
# Out:
#          target
# var_6  0.067746

# %%
corr_df[['target']].iloc[1:][corr_df['target'].iloc[1:] == corr_df['target'].iloc[1:].min()]
# var 81 with lowest correlation
# Out:
#           target
# var_81 -0.082827

# %%
# split data based on the target column, potentially to look for the variable with greatest difference between the groups
grouped_df = dev_df.groupby('target').apply(lambda x: x.mean())
# Out:
# /var/folders/j1/4b075fzj2xdbn0txbrmsq7hm0000gn/T/ipykernel_84132/2880789766.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   grouped_df = dev_df.groupby('target').apply(lambda x: x.mean())

# %%
grouped_df.loc["diff"] = np.abs(grouped_df.loc[0] - grouped_df.loc[1])/(grouped_df.loc[0] + grouped_df.loc[1])

# %%
grouped_df
# Out:
#         target      var_0     var_1      var_2     var_3      var_4     var_5  \
# target
# 0          0.0  10.632715 -1.686058  10.668174  6.791216  11.074759 -5.142848
# 1          1.0  11.171709 -1.037320  11.161679  6.858758  11.127256 -4.342959
# diff       1.0   0.024719 -0.238211   0.022607  0.004948   0.002365 -0.084325
#
#            var_6      var_7     var_8  ...   var_190   var_191   var_192  \
# target                                 ...
# 0       5.390307  16.558966  0.257319  ...  3.147213  7.388435  1.948654
# 1       5.585630  16.534546  0.459915  ...  3.999064  7.881694  1.745621
# diff    0.017796   0.000738  0.282468  ...  0.119202  0.032302  0.054959
#
#          var_193    var_194   var_195   var_196   var_197    var_198   var_199
# target
# 0       3.352043  18.013537 -0.158836  2.252204  8.919978  15.925262 -3.423545
# 1       3.124783  17.773028 -0.014705  2.719763  8.809406  15.399533 -2.507144
# ...

# %%
grouped_df.loc[['diff']].transpose()[grouped_df.loc["diff"] == grouped_df.loc["diff"].max()] # biggest difference
# Out:
# target       diff
# var_170  1.264339

# %%
sns.histplot(dev_df[['target', 'var_170']], x = 'var_170', hue = 'target')
# Out:
# <AxesSubplot: xlabel='var_170', ylabel='Count'>

# %%
sns.histplot(dev_df[['target', 'var_6']], x = 'var_6', hue = 'target')
